# %%
from google.colab import drive
drive.mount('/content/drive')

MAIN_FOLDER = "/content/drive/My Drive/Dentistry/"

# !ls MAIN_FOLDER
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ls: cannot access 'MAIN_FOLDER': No such file or directory

# %%
import pandas as pd
import numpy as np

# %%
# ============================================================
# 1. Load dataset
# ============================================================
FILE_NAME = "list_with_id"

# Read the excel file
df = pd.read_excel(MAIN_FOLDER+FILE_NAME+".xlsx")

# Show the head
df.tail()
# Out:
#       id         name pell_gregory  pederson winter_angulation  age gender_eng
# 795  398  398-SAĞ ALT           2A         7      distoangular   33     female
# 796  399  399-SOL ALT           2A         6          vertical   24     female
# 797  399  399-SAĞ ALT           2A         6          vertical   24     female
# 798  400  400-SOL ALT           2B         6        horizontal   23       male
# 799  400  400-SAĞ ALT           2A         5        horizontal   23       male

# %%
# Extract side information from name column
def extract_side(name):
    name = str(name).upper().strip()

    if "SOL" in name:
        return "left"
    elif "SAĞ" in name or "SAG" in name:
        return "right"
    else:
        return "unknown"

# %%
df["side"] = df["name"].apply(extract_side)

# %%
# Convert Pederson to numeric
df["pederson"] = pd.to_numeric(df["pederson"], errors="coerce")

# %%
# Keep only left and right records
df_lr = df[df["side"].isin(["left", "right"])].copy()
df_lr.tail()
# Out:
#       id         name pell_gregory  pederson winter_angulation  age  \
# 795  398  398-SAĞ ALT           2A         7      distoangular   33
# 796  399  399-SOL ALT           2A         6          vertical   24
# 797  399  399-SAĞ ALT           2A         6          vertical   24
# 798  400  400-SOL ALT           2B         6        horizontal   23
# 799  400  400-SAĞ ALT           2A         5        horizontal   23
#
#     gender_eng   side
# 795     female  right
# 796     female   left
# 797     female  right
# 798       male   left
# 799       male  right

# %%
# Check how many records exist for each patient
patient_side_counts = df_lr.groupby("id")["side"].nunique()

# Keep only patients who have both left and right records
bilateral_patient_ids = patient_side_counts[patient_side_counts == 2].index

df_bilateral = df_lr[df_lr["id"].isin(bilateral_patient_ids)].copy()

print("Number of tooth-level records:", len(df))
print("Number of patients with both left and right records:", len(bilateral_patient_ids))
# Out:
# Number of tooth-level records: 800
# Number of patients with both left and right records: 400

# %%
# Create paired left-right table
paired = df_bilateral.pivot_table(
    index="id",
    columns="side",
    values=["pell_gregory", "pederson", "winter_angulation"],
    aggfunc="first"
)

# Flatten multi-level columns
paired.columns = [f"{variable}_{side}" for variable, side in paired.columns]

# Reset index
paired = paired.reset_index()

print(paired.head())
# Out:
#    id  pederson_left  pederson_right pell_gregory_left pell_gregory_right  \
# 0   1              6               6                2C                 2C
# 1   2              5               5                2B                 2B
# 2   3              6               6                2C                 2C
# 3   4              4               5                1B                 1A
# 4   5              8               7                3C                 2C
#
#   winter_angulation_left winter_angulation_right
# 0           mesioangular            mesioangular
# 1           mesioangular            mesioangular
# 2           mesioangular            mesioangular
# 3           mesioangular                vertical
# 4             horizontal              horizontal

# %%
# Save left and right records into separate Excel files
paired.to_excel("/content/drive/My Drive/Dentistry/paired_list.xlsx", index=False)
